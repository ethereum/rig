# %%
import secrets
from cadCAD.configuration import Configuration
from cadCAD.engine import ExecutionMode, ExecutionContext, Executor
import pandas as pd
from random import uniform
import time

class Transaction:
    def __init__(self, gas_premium, fee_cap, gas_used):
        self.gas_premium = gas_premium
        self.fee_cap = fee_cap
        self.gas_used = gas_used
        self.tx_hash = secrets.token_bytes(8)
        
    def __lt__(self, other):
        return self.gas_premium < other.gas_premium

# %%
constants = {
    "BASEFEE_MAX_CHANGE_DENOMINATOR": 8,
    "TARGET_GAS_USED": 10000000,
    "MAX_GAS_EIP1559": 16000000,
    "EIP1559_DECAY_RANGE": 800000,
    "EIP1559_GAS_INCREMENT_AMOUNT": 10,
    "INITIAL_BASEFEE": 1 * (10 ** 9),
    "PER_TX_GASLIMIT": 8000000
}

# %%
class Block():
    def __init__(self, txs):
        self.txs = txs

# %%
def is_valid(tx, basefee):
    return tx.fee_cap >= basefee

# %%
def update_demand_scenario(params, step, sL, s, _input):
    timestep = s["timestep"]
    demand = s["demand"]
    tx_scenario = s["scenario"]
    
    start = time.time()
    for i in range(tx_scenario[timestep]):
        gas_premium = uniform(1, 11) * (10 ** 9)
        fee_cap = gas_premium + uniform(1, 11) * (10 ** 9)
        tx = Transaction(
            gas_premium = gas_premium,
            gas_used = 21000,
            fee_cap = fee_cap
        )
        demand[tx.tx_hash] = tx
    print("step =", timestep, ", mempool size =", len(demand), ", update demand", time.time() - start)
        
    return ("demand", demand)

# %%
def include_valid_txs(params, step, sL, s):
    demand = s["demand"]
    basefee = s["basefee"]
    timestep = s["timestep"]
    
    start = time.time()
    sorted_valid_demand = sorted([tx for tx_hash, tx in demand.items() if is_valid(tx, basefee)], key = lambda tx: -tx.gas_premium)
    included_transactions = sorted_valid_demand[0:570]
    print("time to sort", time.time() - start)
    
    return ({ "block": Block(txs = included_transactions) })

# %%
def update_basefee(params, step, sL, s, _input):
    block = _input["block"]
    basefee = s["basefee"]
    
    gas_used = sum([tx.gas_used for tx in block.txs])
    delta = gas_used - constants["TARGET_GAS_USED"]
    new_basefee = basefee + basefee * delta // constants["TARGET_GAS_USED"] // constants["BASEFEE_MAX_CHANGE_DENOMINATOR"]
    
    return ("basefee", new_basefee)

# %%
def record_latest_block(params, step, sL, s, _input):
    block = _input["block"]
    
    return ("latest_block", block)

# %%
def remove_included_txs(params, step, sL, s, _input):
    demand = s["demand"]
    latest_block = _input["block"]
    
    start = time.time()
    for tx in latest_block.txs:
        del(demand[tx.tx_hash])
    print("time to remove from txs =", time.time() - start)
        
    return ("demand", demand)

# %%
def end_loop(params, step, sL, s, _input):
    print("loop time", time.time() - s["loop_time"])
    return ("loop_time", time.time())

# %%
from math import pow, exp

timesteps = 300

def generate_spike_scenario(timesteps):
    spikey_boi = timesteps // 8
    return [int(10000 * exp(-pow(i - spikey_boi, 2)/16.0)) for i in range(timesteps)]

tx_scenario = generate_spike_scenario(timesteps)
pd.DataFrame({ "txs": tx_scenario, "producer_limit": 570, "target_gas": 476 }).plot()

# %%
psub = [{
    "policies": {},
    "variables": {
        "demand": update_demand_scenario
    }
}, {
    "policies": {
        "action": include_valid_txs # step 2
    },
    "variables": {
        "demand": remove_included_txs,
        "basefee": update_basefee,
        "latest_block": record_latest_block,
        "loop_time": end_loop
    }
}]

initial_conditions = {
    "scenario": tx_scenario,
    "basefee": 5 * (10 ** 9),
    "demand": {},
    "latest_block": Block(txs=[]),
    "loop_time": time.time()
}

simulation_parameters = {
    'T': range(timesteps),
    'N': 1,
    'M': {}
}

config = Configuration(initial_state=initial_conditions,
                       partial_state_update_blocks=psub,
                       sim_config=simulation_parameters
                      )

exec_mode = ExecutionMode()
exec_context = ExecutionContext(exec_mode.single_proc)
executor = Executor(exec_context, [config]) # Pass the configuration object inside an array
raw_result, tensor = executor.execute() # The `execute()` method returns a tuple; its first elements contains the raw results
df = pd.DataFrame(raw_result)
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: single_proc: [<cadCAD.configuration.Configuration object at 0x123e95080>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x123e95080>]
# step = 0 , mempool size = 0 , update demand 1.9073486328125e-06
# time to sort 3.0994415283203125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.02404022216796875
# step = 1 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 3.0994415283203125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0016362667083740234
# step = 2 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 3.0994415283203125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0016169548034667969
# step = 3 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0016088485717773438
# step = 4 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.6226043701171875e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0015227794647216797
# step = 5 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 3.0994415283203125e-06
# time to remove from txs = 0.0
# loop time 0.0015609264373779297
# step = 6 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 2.86102294921875e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0015816688537597656
# step = 7 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0016319751739501953
# step = 8 , mempool size = 0 , update demand 1.6689300537109375e-06
# time to sort 4.0531158447265625e-06
# time to remove from txs = 0.0
# loop time 0.0016222000122070312
# step = 9 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 4.0531158447265625e-06
# time to remove from txs = 0.0
# loop time 0.0015101432800292969
# step = 10 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 3.0994415283203125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0015647411346435547
# step = 11 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 3.814697265625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0015559196472167969
# step = 12 , mempool size = 0 , update demand 3.814697265625e-06
# time to sort 5.0067901611328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0018529891967773438
# step = 13 , mempool size = 0 , update demand 1.9073486328125e-06
# time to sort 4.0531158447265625e-06
# time to remove from txs = 0.0
# loop time 0.0015931129455566406
# step = 14 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 3.814697265625e-06
# time to remove from txs = 0.0
# loop time 0.001688241958618164
# step = 15 , mempool size = 0 , update demand 1.9073486328125e-06
# time to sort 3.0994415283203125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0016126632690429688
# step = 16 , mempool size = 0 , update demand 1.9073486328125e-06
# time to sort 5.0067901611328125e-06
# time to remove from txs = 0.0
# loop time 0.0017352104187011719
# step = 17 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 4.0531158447265625e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0017211437225341797
# step = 18 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.6226043701171875e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001664876937866211
# step = 19 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 2.86102294921875e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0016770362854003906
# step = 20 , mempool size = 0 , update demand 1.9073486328125e-06
# time to sort 3.814697265625e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0018608570098876953
# step = 21 , mempool size = 0 , update demand 1.9073486328125e-06
# time to sort 5.245208740234375e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001931905746459961
# step = 22 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 3.814697265625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0017681121826171875
# step = 23 , mempool size = 0 , update demand 2.1457672119140625e-06
# time to sort 2.86102294921875e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.001692056655883789
# step = 24 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 3.0994415283203125e-06
# time to remove from txs = 0.0
# loop time 0.0014846324920654297
# step = 25 , mempool size = 1 , update demand 0.00012922286987304688
# time to sort 4.76837158203125e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0016820430755615234
# step = 26 , mempool size = 5 , update demand 0.00031280517578125
# time to sort 7.152557373046875e-06
# time to remove from txs = 1.9073486328125e-06
# loop time 0.001961946487426758
# step = 27 , mempool size = 19 , update demand 0.0008151531219482422
# time to sort 1.2159347534179688e-05
# time to remove from txs = 4.0531158447265625e-06
# loop time 0.0029718875885009766
# step = 28 , mempool size = 63 , update demand 0.0018620491027832031
# time to sort 3.2901763916015625e-05
# time to remove from txs = 1.0967254638671875e-05
# loop time 0.005667209625244141
# step = 29 , mempool size = 183 , update demand 0.010605096817016602
# time to sort 7.915496826171875e-05
# time to remove from txs = 1.5735626220703125e-05
# loop time 0.019015073776245117
# step = 30 , mempool size = 467 , update demand 0.013303995132446289
# time to sort 0.00019097328186035156
# time to remove from txs = 4.00543212890625e-05
# loop time 0.031433820724487305
# step = 31 , mempool size = 1053 , update demand 0.030827045440673828
# time to sort 0.0004780292510986328
# time to remove from txs = 6.198883056640625e-05
# loop time 0.09500598907470703
# step = 32 , mempool size = 2579 , update demand 0.014863014221191406
# time to sort 0.0011360645294189453
# time to remove from txs = 8.20159912109375e-05
# loop time 0.09691286087036133
# step = 33 , mempool size = 5687 , update demand 0.012274026870727539
# time to sort 0.0019299983978271484
# time to remove from txs = 5.3882598876953125e-05
# loop time 0.17181968688964844
# step = 34 , mempool size = 10814 , update demand 0.019639015197753906
# time to sort 0.003985881805419922
# time to remove from txs = 8.797645568847656e-05
# loop time 0.3602941036224365
# step = 35 , mempool size = 18032 , update demand 0.025094032287597656
# time to sort 0.0077550411224365234
# time to remove from txs = 0.0001838207244873047
# loop time 0.6473841667175293
# step = 36 , mempool size = 26856 , update demand 0.029926061630249023
# time to sort 0.01040196418762207
# time to remove from txs = 0.00021004676818847656
# loop time 0.9349579811096191
# step = 37 , mempool size = 36286 , update demand 0.04117012023925781
# time to sort 0.017260074615478516
# time to remove from txs = 0.0002589225769042969
# loop time 1.3925917148590088
# step = 38 , mempool size = 45110 , update demand 0.04116702079772949
# time to sort 0.023327112197875977
# time to remove from txs = 0.00025010108947753906
# loop time 1.7957258224487305
# step = 39 , mempool size = 52328 , update demand 0.031749725341796875
# time to sort 0.02863287925720215
# time to remove from txs = 0.0002701282501220703
# loop time 2.2339508533477783
# step = 40 , mempool size = 57455 , update demand 0.025619983673095703
# time to sort 0.0334782600402832
# time to remove from txs = 0.00037288665771484375
# loop time 2.4501712322235107
# step = 41 , mempool size = 60563 , update demand 0.014838218688964844
# time to sort 0.03509926795959473
# time to remove from txs = 0.0002872943878173828
# loop time 2.6340088844299316
# step = 42 , mempool size = 62089 , update demand 0.008209228515625
# time to sort 0.03849315643310547
# time to remove from txs = 0.0003209114074707031
# loop time 2.8747379779815674
# step = 43 , mempool size = 62572 , update demand 0.004791736602783203
# time to sort 0.039272308349609375
# time to remove from txs = 0.00032591819763183594
# loop time 3.0185608863830566
# step = 44 , mempool size = 62469 , update demand 0.001961946487426758
# time to sort 0.04126906394958496
# time to remove from txs = 0.00032711029052734375
# loop time 3.127718210220337
# step = 45 , mempool size = 62082 , update demand 0.0007233619689941406
# time to sort 0.03797411918640137
# time to remove from txs = 0.00031685829162597656
# loop time 2.6816937923431396
# step = 46 , mempool size = 61575 , update demand 0.0002739429473876953
# time to sort 0.0376589298248291
# time to remove from txs = 0.00030493736267089844
# loop time 2.7811520099639893
# step = 47 , mempool size = 61024 , update demand 9.608268737792969e-05
# time to sort 0.03539109230041504
# time to remove from txs = 0.00029206275939941406
# loop time 2.764206886291504
# step = 48 , mempool size = 60459 , update demand 5.6743621826171875e-05
# time to sort 0.04062390327453613
# time to remove from txs = 0.0003120899200439453
# loop time 2.7546398639678955
# step = 49 , mempool size = 59890 , update demand 2.7179718017578125e-05
# time to sort 0.03655600547790527
# time to remove from txs = 0.00032806396484375
# loop time 2.995651960372925
# step = 50 , mempool size = 59320 , update demand 2.1457672119140625e-06
# time to sort 0.037490129470825195
# time to remove from txs = 0.00033593177795410156
# loop time 3.046170234680176
# step = 51 , mempool size = 58750 , update demand 3.0994415283203125e-06
# time to sort 0.03562021255493164
# time to remove from txs = 0.0003731250762939453
# loop time 2.479398012161255
# step = 52 , mempool size = 58180 , update demand 2.1457672119140625e-06
# time to sort 0.040151119232177734
# time to remove from txs = 0.0004260540008544922
# loop time 3.037309169769287
# step = 53 , mempool size = 57610 , update demand 1.9073486328125e-06
# time to sort 0.03524208068847656
# time to remove from txs = 0.0003421306610107422
# loop time 2.6718881130218506
# step = 54 , mempool size = 57040 , update demand 9.5367431640625e-07
# time to sort 0.038130998611450195
# time to remove from txs = 0.0003380775451660156
# loop time 2.5578720569610596
# step = 55 , mempool size = 56470 , update demand 2.1457672119140625e-06
# time to sort 0.032608985900878906
# time to remove from txs = 0.00027179718017578125
# loop time 2.801076889038086
# step = 56 , mempool size = 55900 , update demand 3.0994415283203125e-06
# time to sort 0.03503894805908203
# time to remove from txs = 0.0003230571746826172
# loop time 2.312575340270996
# step = 57 , mempool size = 55330 , update demand 2.1457672119140625e-06
# time to sort 0.033318281173706055
# time to remove from txs = 0.00041985511779785156
# loop time 2.739898920059204
# step = 58 , mempool size = 54760 , update demand 2.1457672119140625e-06
# time to sort 0.0330662727355957
# time to remove from txs = 0.0002808570861816406
# loop time 2.278687000274658
# step = 59 , mempool size = 54190 , update demand 2.1457672119140625e-06
# time to sort 0.030884265899658203
# time to remove from txs = 0.00027871131896972656
# loop time 2.2451419830322266
# step = 60 , mempool size = 53620 , update demand 2.1457672119140625e-06
# time to sort 0.03485512733459473
# time to remove from txs = 0.00028014183044433594
# loop time 2.7091798782348633
# step = 61 , mempool size = 53050 , update demand 2.1457672119140625e-06
# time to sort 0.03513526916503906
# time to remove from txs = 0.0003452301025390625
# loop time 2.470949172973633
# step = 62 , mempool size = 52480 , update demand 1.9073486328125e-06
# time to sort 0.03203320503234863
# time to remove from txs = 0.0002951622009277344
# loop time 2.2864160537719727
# step = 63 , mempool size = 51910 , update demand 2.1457672119140625e-06
# time to sort 0.031215190887451172
# time to remove from txs = 0.0002791881561279297
# loop time 2.208246946334839
# step = 64 , mempool size = 51340 , update demand 2.1457672119140625e-06
# time to sort 0.032588958740234375
# time to remove from txs = 0.0003399848937988281
# loop time 2.7469592094421387
# step = 65 , mempool size = 50770 , update demand 1.9073486328125e-06
# time to sort 0.030311107635498047
# time to remove from txs = 0.0003368854522705078
# loop time 2.1726603507995605
# step = 66 , mempool size = 50200 , update demand 1.9073486328125e-06
# time to sort 0.031970977783203125
# time to remove from txs = 0.0003159046173095703
# loop time 2.138554096221924
# step = 67 , mempool size = 49630 , update demand 3.0994415283203125e-06
# time to sort 0.034037113189697266
# time to remove from txs = 0.00034308433532714844
# loop time 2.229137897491455
# step = 68 , mempool size = 49060 , update demand 1.9073486328125e-06
# time to sort 0.028828859329223633
# time to remove from txs = 0.0002651214599609375
# loop time 3.047450065612793
# step = 69 , mempool size = 48490 , update demand 2.1457672119140625e-06
# time to sort 0.02806401252746582
# time to remove from txs = 0.0002837181091308594
# loop time 2.1310298442840576
# step = 70 , mempool size = 47920 , update demand 3.0994415283203125e-06
# time to sort 0.030727863311767578
# time to remove from txs = 0.0004520416259765625
# loop time 2.1931190490722656
# step = 71 , mempool size = 47350 , update demand 1.6689300537109375e-06
# time to sort 0.02762603759765625
# time to remove from txs = 0.0002701282501220703
# loop time 2.130720853805542
# step = 72 , mempool size = 46780 , update demand 1.9073486328125e-06
# time to sort 0.027518033981323242
# time to remove from txs = 0.00026702880859375
# loop time 1.969383955001831
# step = 73 , mempool size = 46210 , update demand 2.1457672119140625e-06
# time to sort 0.02947521209716797
# time to remove from txs = 0.00031185150146484375
# loop time 2.607267141342163
# step = 74 , mempool size = 45640 , update demand 2.1457672119140625e-06
# time to sort 0.03158974647521973
# time to remove from txs = 0.0004410743713378906
# loop time 2.075756072998047
# step = 75 , mempool size = 45070 , update demand 1.9073486328125e-06
# time to sort 0.030181884765625
# time to remove from txs = 0.00032401084899902344
# loop time 2.1495041847229004
# step = 76 , mempool size = 44500 , update demand 1.6689300537109375e-06
# time to sort 0.02626824378967285
# time to remove from txs = 0.0002779960632324219
# loop time 1.9359660148620605
# step = 77 , mempool size = 43930 , update demand 1.9073486328125e-06
# time to sort 0.025603294372558594
# time to remove from txs = 0.00029730796813964844
# loop time 1.9646871089935303
# step = 78 , mempool size = 43360 , update demand 1.9073486328125e-06
# time to sort 0.02615809440612793
# time to remove from txs = 0.000270843505859375
# loop time 1.8783040046691895
# step = 79 , mempool size = 42790 , update demand 3.0994415283203125e-06
# time to sort 0.026190996170043945
# time to remove from txs = 0.0003311634063720703
# loop time 2.56463623046875
# step = 80 , mempool size = 42220 , update demand 1.9073486328125e-06
# time to sort 0.0270233154296875
# time to remove from txs = 0.000347137451171875
# loop time 1.8506529331207275
# step = 81 , mempool size = 41650 , update demand 1.9073486328125e-06
# time to sort 0.024347782135009766
# time to remove from txs = 0.00028324127197265625
# loop time 1.8266627788543701
# step = 82 , mempool size = 41080 , update demand 1.9073486328125e-06
# time to sort 0.02435302734375
# time to remove from txs = 0.00027108192443847656
# loop time 1.850377082824707
# step = 83 , mempool size = 40510 , update demand 1.6689300537109375e-06
# time to sort 0.02358388900756836
# time to remove from txs = 0.00026702880859375
# loop time 1.9581687450408936
# step = 84 , mempool size = 39940 , update demand 2.86102294921875e-06
# time to sort 0.027267932891845703
# time to remove from txs = 0.0003681182861328125
# loop time 1.8300502300262451
# step = 85 , mempool size = 39370 , update demand 1.1920928955078125e-06
# time to sort 0.026705026626586914
# time to remove from txs = 0.0004420280456542969
# loop time 1.9273028373718262
# step = 86 , mempool size = 38800 , update demand 9.5367431640625e-07
# time to sort 0.02640390396118164
# time to remove from txs = 0.0003459453582763672
# loop time 1.6969819068908691
# step = 87 , mempool size = 38230 , update demand 3.0994415283203125e-06
# time to sort 0.02254486083984375
# time to remove from txs = 0.00025177001953125
# loop time 2.6508219242095947
# step = 88 , mempool size = 37660 , update demand 2.1457672119140625e-06
# time to sort 0.021239042282104492
# time to remove from txs = 0.0002529621124267578
# loop time 1.7817049026489258
# step = 89 , mempool size = 37090 , update demand 2.1457672119140625e-06
# time to sort 0.02398681640625
# time to remove from txs = 0.0003299713134765625
# loop time 1.6102521419525146
# step = 90 , mempool size = 36520 , update demand 1.6689300537109375e-06
# time to sort 0.020772695541381836
# time to remove from txs = 0.0002818107604980469
# loop time 1.521610975265503
# step = 91 , mempool size = 35950 , update demand 3.0994415283203125e-06
# time to sort 0.02223992347717285
# time to remove from txs = 0.00030684471130371094
# loop time 1.646409034729004
# step = 92 , mempool size = 35380 , update demand 3.0994415283203125e-06
# time to sort 0.028465986251831055
# time to remove from txs = 0.00033402442932128906
# loop time 1.9224562644958496
# step = 93 , mempool size = 34810 , update demand 3.0994415283203125e-06
# time to sort 0.020835161209106445
# time to remove from txs = 0.00030517578125
# loop time 1.8434460163116455
# step = 94 , mempool size = 34240 , update demand 1.9073486328125e-06
# time to sort 0.01879715919494629
# time to remove from txs = 0.0002689361572265625
# loop time 1.444584846496582
# step = 95 , mempool size = 33670 , update demand 1.9073486328125e-06
# time to sort 0.0183260440826416
# time to remove from txs = 0.00024771690368652344
# loop time 1.3822250366210938
# step = 96 , mempool size = 33100 , update demand 3.0994415283203125e-06
# time to sort 0.0228118896484375
# time to remove from txs = 0.0003161430358886719
# loop time 2.5531809329986572
# step = 97 , mempool size = 32530 , update demand 2.1457672119140625e-06
# time to sort 0.01778578758239746
# time to remove from txs = 0.00024008750915527344
# loop time 1.4559452533721924
# step = 98 , mempool size = 31960 , update demand 9.5367431640625e-07
# time to sort 0.018110036849975586
# time to remove from txs = 0.00026488304138183594
# loop time 1.3422207832336426
# step = 99 , mempool size = 31390 , update demand 9.5367431640625e-07
# time to sort 0.015437126159667969
# time to remove from txs = 0.0002498626708984375
# loop time 1.275554895401001
# step = 100 , mempool size = 30820 , update demand 1.6689300537109375e-06
# time to sort 0.01502370834350586
# time to remove from txs = 0.00023102760314941406
# loop time 1.2562239170074463
# step = 101 , mempool size = 30250 , update demand 2.1457672119140625e-06
# time to sort 0.01371312141418457
# time to remove from txs = 0.00020503997802734375
# loop time 1.238368034362793
# step = 102 , mempool size = 29680 , update demand 1.9073486328125e-06
# time to sort 0.01428675651550293
# time to remove from txs = 0.000240325927734375
# loop time 1.2173690795898438
# step = 103 , mempool size = 29110 , update demand 2.1457672119140625e-06
# time to sort 0.013058900833129883
# time to remove from txs = 0.00019478797912597656
# loop time 1.1914961338043213
# step = 104 , mempool size = 28540 , update demand 1.9073486328125e-06
# time to sort 0.01417088508605957
# time to remove from txs = 0.00022029876708984375
# loop time 1.1578660011291504
# step = 105 , mempool size = 27970 , update demand 2.1457672119140625e-06
# time to sort 0.01287078857421875
# time to remove from txs = 0.00019979476928710938
# loop time 1.1758570671081543
# step = 106 , mempool size = 27400 , update demand 1.9073486328125e-06
# time to sort 0.013479948043823242
# time to remove from txs = 0.00021028518676757812
# loop time 1.1214749813079834
# step = 107 , mempool size = 26830 , update demand 9.5367431640625e-07
# time to sort 0.012779951095581055
# time to remove from txs = 0.00020623207092285156
# loop time 1.0928092002868652
# step = 108 , mempool size = 26260 , update demand 1.9073486328125e-06
# time to sort 0.01406097412109375
# time to remove from txs = 0.0002219676971435547
# loop time 2.097330093383789
# step = 109 , mempool size = 25690 , update demand 2.86102294921875e-06
# time to sort 0.014664888381958008
# time to remove from txs = 0.000209808349609375
# loop time 1.0580759048461914
# step = 110 , mempool size = 25120 , update demand 2.1457672119140625e-06
# time to sort 0.014442920684814453
# time to remove from txs = 0.00022721290588378906
# loop time 1.0479018688201904
# step = 111 , mempool size = 24550 , update demand 1.9073486328125e-06
# time to sort 0.01359105110168457
# time to remove from txs = 0.00023102760314941406
# loop time 1.0154697895050049
# step = 112 , mempool size = 23980 , update demand 1.9073486328125e-06
# time to sort 0.014199972152709961
# time to remove from txs = 0.00023889541625976562
# loop time 0.9889860153198242
# step = 113 , mempool size = 23410 , update demand 2.1457672119140625e-06
# time to sort 0.01357579231262207
# time to remove from txs = 0.00023293495178222656
# loop time 0.9789948463439941
# step = 114 , mempool size = 22840 , update demand 1.9073486328125e-06
# time to sort 0.012439966201782227
# time to remove from txs = 0.00022602081298828125
# loop time 0.9482271671295166
# step = 115 , mempool size = 22270 , update demand 1.9073486328125e-06
# time to sort 0.01322484016418457
# time to remove from txs = 0.0002810955047607422
# loop time 0.9548389911651611
# step = 116 , mempool size = 21700 , update demand 2.1457672119140625e-06
# time to sort 0.012497901916503906
# time to remove from txs = 0.00019669532775878906
# loop time 0.93184494972229
# step = 117 , mempool size = 21130 , update demand 2.1457672119140625e-06
# time to sort 0.011667013168334961
# time to remove from txs = 0.000179290771484375
# loop time 0.8752679824829102
# step = 118 , mempool size = 20560 , update demand 1.9073486328125e-06
# time to sort 0.010864973068237305
# time to remove from txs = 0.0001838207244873047
# loop time 0.8628132343292236
# step = 119 , mempool size = 19990 , update demand 2.6226043701171875e-06
# time to sort 0.01173710823059082
# time to remove from txs = 0.00018477439880371094
# loop time 0.8399612903594971
# step = 120 , mempool size = 19420 , update demand 2.1457672119140625e-06
# time to sort 0.009849071502685547
# time to remove from txs = 0.0001709461212158203
# loop time 0.8105809688568115
# step = 121 , mempool size = 18850 , update demand 2.1457672119140625e-06
# time to sort 0.009460926055908203
# time to remove from txs = 0.00018215179443359375
# loop time 0.7900779247283936
# step = 122 , mempool size = 18280 , update demand 2.1457672119140625e-06
# time to sort 0.009598970413208008
# time to remove from txs = 0.0001728534698486328
# loop time 0.7454938888549805
# step = 123 , mempool size = 17710 , update demand 2.1457672119140625e-06
# time to sort 0.008674860000610352
# time to remove from txs = 0.00015783309936523438
# loop time 0.7462689876556396
# step = 124 , mempool size = 17140 , update demand 1.9073486328125e-06
# time to sort 0.008358955383300781
# time to remove from txs = 0.0001480579376220703
# loop time 0.7170670032501221
# step = 125 , mempool size = 16570 , update demand 2.86102294921875e-06
# time to sort 0.007950067520141602
# time to remove from txs = 0.00015091896057128906
# loop time 0.7027347087860107
# step = 126 , mempool size = 16000 , update demand 9.5367431640625e-07
# time to sort 0.007727861404418945
# time to remove from txs = 0.00013780593872070312
# loop time 0.6625180244445801
# step = 127 , mempool size = 15430 , update demand 2.86102294921875e-06
# time to sort 0.007402896881103516
# time to remove from txs = 0.00014209747314453125
# loop time 0.6560649871826172
# step = 128 , mempool size = 14860 , update demand 1.9073486328125e-06
# time to sort 0.007336854934692383
# time to remove from txs = 0.00013780593872070312
# loop time 0.6294729709625244
# step = 129 , mempool size = 14290 , update demand 2.1457672119140625e-06
# time to sort 0.0069620609283447266
# time to remove from txs = 0.00014781951904296875
# loop time 1.731801986694336
# step = 130 , mempool size = 13720 , update demand 2.1457672119140625e-06
# time to sort 0.006785154342651367
# time to remove from txs = 0.0001556873321533203
# loop time 0.6207501888275146
# step = 131 , mempool size = 13150 , update demand 1.9073486328125e-06
# time to sort 0.006498098373413086
# time to remove from txs = 0.00011801719665527344
# loop time 0.5548152923583984
# step = 132 , mempool size = 12580 , update demand 3.0994415283203125e-06
# time to sort 0.006147146224975586
# time to remove from txs = 0.0001347064971923828
# loop time 0.5424530506134033
# step = 133 , mempool size = 12010 , update demand 2.1457672119140625e-06
# time to sort 0.006009101867675781
# time to remove from txs = 0.00013327598571777344
# loop time 0.5091440677642822
# step = 134 , mempool size = 11440 , update demand 1.9073486328125e-06
# time to sort 0.00551295280456543
# time to remove from txs = 0.00011396408081054688
# loop time 0.4949960708618164
# step = 135 , mempool size = 10870 , update demand 2.1457672119140625e-06
# time to sort 0.005552768707275391
# time to remove from txs = 0.00012493133544921875
# loop time 0.4730689525604248
# step = 136 , mempool size = 10300 , update demand 2.1457672119140625e-06
# time to sort 0.004917144775390625
# time to remove from txs = 0.00010323524475097656
# loop time 0.4493749141693115
# step = 137 , mempool size = 9730 , update demand 1.9073486328125e-06
# time to sort 0.0059032440185546875
# time to remove from txs = 0.0001380443572998047
# loop time 0.41737914085388184
# step = 138 , mempool size = 9160 , update demand 9.5367431640625e-07
# time to sort 0.005112886428833008
# time to remove from txs = 0.00017690658569335938
# loop time 0.40366077423095703
# step = 139 , mempool size = 8590 , update demand 1.1920928955078125e-06
# time to sort 0.004533052444458008
# time to remove from txs = 0.00011610984802246094
# loop time 0.3957808017730713
# step = 140 , mempool size = 8020 , update demand 3.0994415283203125e-06
# time to sort 0.004029989242553711
# time to remove from txs = 0.00020885467529296875
# loop time 0.35801196098327637
# step = 141 , mempool size = 7450 , update demand 1.9073486328125e-06
# time to sort 0.0032198429107666016
# time to remove from txs = 7.796287536621094e-05
# loop time 0.34479808807373047
# step = 142 , mempool size = 6880 , update demand 2.1457672119140625e-06
# time to sort 0.0031270980834960938
# time to remove from txs = 7.295608520507812e-05
# loop time 0.2987382411956787
# step = 143 , mempool size = 6310 , update demand 2.1457672119140625e-06
# time to sort 0.002679109573364258
# time to remove from txs = 7.200241088867188e-05
# loop time 0.28092193603515625
# step = 144 , mempool size = 5740 , update demand 9.5367431640625e-07
# time to sort 0.0032923221588134766
# time to remove from txs = 0.00010704994201660156
# loop time 0.26353001594543457
# step = 145 , mempool size = 5170 , update demand 9.5367431640625e-07
# time to sort 0.002190828323364258
# time to remove from txs = 7.390975952148438e-05
# loop time 0.24351000785827637
# step = 146 , mempool size = 4600 , update demand 1.9073486328125e-06
# time to sort 0.001875162124633789
# time to remove from txs = 0.00010395050048828125
# loop time 0.2078859806060791
# step = 147 , mempool size = 4030 , update demand 9.5367431640625e-07
# time to sort 0.0018439292907714844
# time to remove from txs = 6.914138793945312e-05
# loop time 0.19686603546142578
# step = 148 , mempool size = 3460 , update demand 2.1457672119140625e-06
# time to sort 0.0016279220581054688
# time to remove from txs = 6.389617919921875e-05
# loop time 0.17391681671142578
# step = 149 , mempool size = 2890 , update demand 2.1457672119140625e-06
# time to sort 0.0015020370483398438
# time to remove from txs = 6.508827209472656e-05
# loop time 0.15450811386108398
# step = 150 , mempool size = 2320 , update demand 2.1457672119140625e-06
# time to sort 0.0009348392486572266
# time to remove from txs = 6.079673767089844e-05
# loop time 0.1240239143371582
# step = 151 , mempool size = 1750 , update demand 1.9073486328125e-06
# time to sort 0.0006687641143798828
# time to remove from txs = 5.602836608886719e-05
# loop time 0.10002875328063965
# step = 152 , mempool size = 1180 , update demand 9.5367431640625e-07
# time to sort 0.0006871223449707031
# time to remove from txs = 7.319450378417969e-05
# loop time 0.08077216148376465
# step = 153 , mempool size = 610 , update demand 1.9073486328125e-06
# time to sort 0.0003509521484375
# time to remove from txs = 7.200241088867188e-05
# loop time 0.06920886039733887
# step = 154 , mempool size = 40 , update demand 7.152557373046875e-07
# time to sort 1.9073486328125e-05
# time to remove from txs = 5.245208740234375e-06
# loop time 0.03947091102600098
# step = 155 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.00834202766418457
# step = 156 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0016970634460449219
# step = 157 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0013151168823242188
# step = 158 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.001264810562133789
# step = 159 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0012450218200683594
# step = 160 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001222848892211914
# step = 161 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.001207113265991211
# step = 162 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0012087821960449219
# step = 163 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011839866638183594
# step = 164 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001188039779663086
# step = 165 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0011670589447021484
# step = 166 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0015630722045898438
# step = 167 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0011930465698242188
# step = 168 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0010540485382080078
# step = 169 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001168966293334961
# step = 170 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011851787567138672
# step = 171 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0012011528015136719
# step = 172 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.0012280941009521484
# step = 173 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0012202262878417969
# step = 174 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011858940124511719
# step = 175 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0013549327850341797
# step = 176 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0011980533599853516
# step = 177 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011887550354003906
# step = 178 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001264333724975586
# step = 179 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0012371540069580078
# step = 180 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012328624725341797
# step = 181 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0012171268463134766
# step = 182 , mempool size = 0 , update demand 0.0
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0011899471282958984
# step = 183 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0012488365173339844
# step = 184 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011909008026123047
# step = 185 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011749267578125
# step = 186 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0013337135314941406
# step = 187 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.1920928955078125e-06
# time to remove from txs = 0.0
# loop time 0.0011920928955078125
# step = 188 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.001110076904296875
# step = 189 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 7.152557373046875e-07
# time to remove from txs = 0.0
# loop time 0.0012049674987792969
# step = 190 , mempool size = 0 , update demand 0.0
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0012259483337402344
# step = 191 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0011818408966064453
# step = 192 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0012140274047851562
# step = 193 , mempool size = 0 , update demand 0.0
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0011830329895019531
# step = 194 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.001374959945678711
# step = 195 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.001194000244140625
# step = 196 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.001580953598022461
# step = 197 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.00121307373046875
# step = 198 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.001361846923828125
# step = 199 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0010828971862792969
# step = 200 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001154184341430664
# step = 201 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.1920928955078125e-06
# time to remove from txs = 0.0
# loop time 0.001331329345703125
# step = 202 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0011539459228515625
# step = 203 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012471675872802734
# step = 204 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011849403381347656
# step = 205 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0014348030090332031
# step = 206 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0012481212615966797
# step = 207 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 0.0001678466796875
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0016489028930664062
# step = 208 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0013859272003173828
# step = 209 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0011868476867675781
# step = 210 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.6689300537109375e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0013630390167236328
# step = 211 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001207113265991211
# step = 212 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0011589527130126953
# step = 213 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.1920928955078125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011909008026123047
# step = 214 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0011959075927734375
# step = 215 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.00127410888671875
# step = 216 , mempool size = 0 , update demand 0.0
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0011899471282958984
# step = 217 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.0011949539184570312
# step = 218 , mempool size = 0 , update demand 0.0
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011682510375976562
# step = 219 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0012507438659667969
# step = 220 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011761188507080078
# step = 221 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.001462697982788086
# step = 222 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.001377105712890625
# step = 223 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.09808349609375e-05
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012819766998291016
# step = 224 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0013129711151123047
# step = 225 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011529922485351562
# step = 226 , mempool size = 0 , update demand 0.0
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0013461112976074219
# step = 227 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012061595916748047
# step = 228 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 7.152557373046875e-07
# loop time 0.0013921260833740234
# step = 229 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012271404266357422
# step = 230 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0010597705841064453
# step = 231 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0014109611511230469
# step = 232 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011739730834960938
# step = 233 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0011708736419677734
# step = 234 , mempool size = 0 , update demand 0.0
# time to sort 2.1457672119140625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0014729499816894531
# step = 235 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.0011591911315917969
# step = 236 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012121200561523438
# step = 237 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0014541149139404297
# step = 238 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 7.152557373046875e-07
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0012619495391845703
# step = 239 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0014338493347167969
# step = 240 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0013270378112792969
# step = 241 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.04169178009033203
# step = 242 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0013158321380615234
# step = 243 , mempool size = 0 , update demand 0.0
# time to sort 9.5367431640625e-07
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0011548995971679688
# step = 244 , mempool size = 0 , update demand 0.0
# time to sort 9.5367431640625e-07
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.001155853271484375
# step = 245 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.0011849403381347656
# step = 246 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0011820793151855469
# step = 247 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0011699199676513672
# step = 248 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.6689300537109375e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0014238357543945312
# step = 249 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0013859272003173828
# step = 250 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0012371540069580078
# step = 251 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0011298656463623047
# step = 252 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0010638236999511719
# step = 253 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011980533599853516
# step = 254 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0013508796691894531
# step = 255 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0012688636779785156
# step = 256 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0013849735260009766
# step = 257 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0011970996856689453
# step = 258 , mempool size = 0 , update demand 0.0
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.001399993896484375
# step = 259 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0014069080352783203
# step = 260 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012598037719726562
# step = 261 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0012159347534179688
# step = 262 , mempool size = 0 , update demand 0.0
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0014247894287109375
# step = 263 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011782646179199219
# step = 264 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0013303756713867188
# step = 265 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011670589447021484
# step = 266 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0012459754943847656
# step = 267 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001489877700805664
# step = 268 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.001560211181640625
# step = 269 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.001386880874633789
# step = 270 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 9.5367431640625e-07
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.001165151596069336
# step = 271 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0013659000396728516
# step = 272 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0014667510986328125
# step = 273 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.9073486328125e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0015101432800292969
# step = 274 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0010709762573242188
# step = 275 , mempool size = 0 , update demand 0.0
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0010561943054199219
# step = 276 , mempool size = 0 , update demand 0.0
# time to sort 7.152557373046875e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0011777877807617188
# step = 277 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 0.0
# loop time 0.0014121532440185547
# step = 278 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0014481544494628906
# step = 279 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0013918876647949219
# step = 280 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0010800361633300781
# step = 281 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0012309551239013672
# step = 282 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 0.0
# loop time 0.0012297630310058594
# step = 283 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.04234814643859863
# step = 284 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0013439655303955078
# step = 285 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.6689300537109375e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012440681457519531
# step = 286 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0012259483337402344
# step = 287 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.001280069351196289
# step = 288 , mempool size = 0 , update demand 0.0
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0012431144714355469
# step = 289 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 0.0
# loop time 0.0016529560089111328
# step = 290 , mempool size = 0 , update demand 3.0994415283203125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0015330314636230469
# step = 291 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0013623237609863281
# step = 292 , mempool size = 0 , update demand 7.152557373046875e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.002475738525390625
# step = 293 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.1920928955078125e-06
# time to remove from txs = 0.0
# loop time 0.0013048648834228516
# step = 294 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 1.9073486328125e-06
# time to remove from txs = 0.0
# loop time 0.0013859272003173828
# step = 295 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.1920928955078125e-06
# time to remove from txs = 0.0
# loop time 0.001310110092163086
# step = 296 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 2.1457672119140625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.00128173828125
# step = 297 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 2.1457672119140625e-06
# time to remove from txs = 1.1920928955078125e-06
# loop time 0.0012669563293457031
# step = 298 , mempool size = 0 , update demand 9.5367431640625e-07
# time to sort 9.5367431640625e-07
# time to remove from txs = 9.5367431640625e-07
# loop time 0.0012650489807128906
# step = 299 , mempool size = 0 , update demand 1.1920928955078125e-06
# time to sort 1.1920928955078125e-06
# time to remove from txs = 0.0
# loop time 0.0012640953063964844

# %%
df[df.substep == 1].plot("timestep", "basefee")

# %%
df["mempool_size"] = df.demand.apply(
    lambda demand: len(demand)
)
df[df.substep == 1].plot("timestep", "mempool_size")

# %%
df["included_txs"] = df.latest_block.apply(
    lambda block: len(block.txs)
)
df[df.substep == 1].plot("timestep", "included_txs")
